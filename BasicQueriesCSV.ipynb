# %% [markdown]
# ## **Basic Queries At CSV files**

# %% [markdown]
# Import CSV Dataframe

# %% [markdown]
# Import Pandas

# %%
import pandas as pd

# %% [markdown]
# Import Dataset CSV file from Google **Drive**

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **Read and Print CSV file**

# %%
data = pd.read_csv("gdrive/My Drive/Northwindcsv/Products.csv")
print(data)
# Out:
#     ProductID                      ProductName  SupplierID  CategoryID  \
# 0           1                             Chai           1           1
# 1           2                            Chang           1           1
# 2           3                    Aniseed Syrup           1           2
# 3           4     Chef Anton's Cajun Seasoning           2           2
# 4           5           Chef Anton's Gumbo Mix           2           2
# ..        ...                              ...         ...         ...
# 72         73                       Röd Kaviar          17           8
# 73         74                    Longlife Tofu           4           7
# 74         75             Rhönbräu Klosterbier          12           1
# 75         76                     Lakkalikööri          23           1
# 76         77  Original Frankfurter grüne Soße          12           2
#
#         QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# ...

# %% [markdown]
# with heads

# %%
data = pd.read_csv("gdrive/My Drive/Northwindcsv/Products.csv")
data.head()
# Out:
#    ProductID                   ProductName  SupplierID  CategoryID  \
# 0          1                          Chai           1           1
# 1          2                         Chang           1           1
# 2          3                 Aniseed Syrup           1           2
# 3          4  Chef Anton's Cajun Seasoning           2           2
# 4          5        Chef Anton's Gumbo Mix           2           2
#
#        QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# 0   10 boxes x 20 bags      18.00            39             0            10
# 1   24 - 12 oz bottles      19.00            17            40            25
# 2  12 - 550 ml bottles      10.00            13            70            25
# 3       48 - 6 oz jars      22.00            53             0             0
# 4             36 boxes      21.35             0             0             0
#
#    Discontinued
# 0             0
# 1             0
# 2             0
# 3             0
# 4             1

# %% [markdown]
# # **Query Select**

# %%
data[['ProductID', 'ProductName', 'SupplierID', 'CategoryID', 'QuantityPerUnit', 'UnitPrice', 'UnitsInStock', 'UnitsOnOrder', 'ReorderLevel', 'Discontinued']]
# Out:
#     ProductID                      ProductName  SupplierID  CategoryID  \
# 0           1                             Chai           1           1
# 1           2                            Chang           1           1
# 2           3                    Aniseed Syrup           1           2
# 3           4     Chef Anton's Cajun Seasoning           2           2
# 4           5           Chef Anton's Gumbo Mix           2           2
# ..        ...                              ...         ...         ...
# 72         73                       Röd Kaviar          17           8
# 73         74                    Longlife Tofu           4           7
# 74         75             Rhönbräu Klosterbier          12           1
# 75         76                     Lakkalikööri          23           1
# 76         77  Original Frankfurter grüne Soße          12           2
#
#         QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# ...

# %% [markdown]
# # **Query WHERE**

# %% [markdown]
# where UnitPrice > 20

# %%
data[data['UnitPrice'] > 20]
# Out:
#     ProductID                       ProductName  SupplierID  CategoryID  \
# 3           4      Chef Anton's Cajun Seasoning           2           2
# 4           5            Chef Anton's Gumbo Mix           2           2
# 5           6      Grandma's Boysenberry Spread           3           2
# 6           7   Uncle Bob's Organic Dried Pears           3           7
# 7           8        Northwoods Cranberry Sauce           3           2
# 8           9                   Mishi Kobe Niku           4           6
# 9          10                             Ikura           4           8
# 10         11                    Queso Cabrales           5           4
# 11         12         Queso Manchego La Pastora           5           4
# 13         14                              Tofu           6           7
# 16         17                      Alice Mutton           7           6
# 17         18                  Carnarvon Tigers           7           8
# ...

# %% [markdown]
# where QuantityPerUnit = 24 - 12 oz bottles

# %%
data[data['QuantityPerUnit'] == '24 - 12 oz bottles']
# Out:
#     ProductID                ProductName  SupplierID  CategoryID  \
# 1           2                      Chang           1           1
# 33         34              Sasquatch Ale          16           1
# 34         35             Steeleye Stout          16           1
# 66         67  Laughing Lumberjack Lager          16           1
#
#        QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# 1   24 - 12 oz bottles       19.0            17            40            25
# 33  24 - 12 oz bottles       14.0           111             0            15
# 34  24 - 12 oz bottles       18.0            20             0            15
# 66  24 - 12 oz bottles       14.0            52             0            10
#
#     Discontinued
# 1              0
# 33             0
# 34             0
# 66             0
