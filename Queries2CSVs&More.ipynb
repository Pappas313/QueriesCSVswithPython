# %% [markdown]
# <a href="https://colab.research.google.com/github/Pappas313/QueriesCSVswithPython/blob/main/Queries2CSVs%26More.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IMPORT CSVs Libraries**

# %%
import csv
import pandas as pd
import numpy as np

# %% [markdown]
# **Import CSVs**

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# reading two csv files
Customers = pd.read_csv("gdrive/My Drive/Northwindcsv/Customers.csv")
Orders = pd.read_csv('gdrive/My Drive/Northwindcsv/Orders.csv')

# %%
Customers.head(1000)
# Out:
#    CustomerID                         CompanyName              ContactName  \
# 0       ALFKI                 Alfreds Futterkiste             Maria Anders
# 1       ANATR  Ana Trujillo Emparedados y helados             Ana Trujillo
# 2       ANTON             Antonio Moreno Taquería           Antonio Moreno
# 3       AROUT                     Around the Horn             Thomas Hardy
# 4       BERGS                  Berglunds snabbköp       Christina Berglund
# ..        ...                                 ...                      ...
# 86      WARTH                      Wartian Herkku         Pirkko Koskitalo
# 87      WELLI              Wellington Importadora            Paula Parente
# 88      WHITC                White Clover Markets           Karl Jablonski
# 89      WILMK                         Wilman Kala          Matti Karttunen
# 90      WOLZA                      Wolski  Zajazd  Zbyszek Piestrzeniewicz
#
# ...

# %%
Orders.head(1000)
# Out:
#      OrderID CustomerID  EmployeeID                OrderDate  \
# 0      10389      BOTTM           4  1995-01-20 00:00:00.000
# 1      10390      ERNSH           6  1995-01-23 00:00:00.000
# 2      10391      DRACD           3  1995-01-23 00:00:00.000
# 3      10392      PICCO           2  1995-01-24 00:00:00.000
# 4      10393      SAVEA           1  1995-01-25 00:00:00.000
# ..       ...        ...         ...                      ...
# 825    11073      PERIC           2  1996-06-04 00:00:00.000
# 826    11074      SIMOB           7  1996-06-05 00:00:00.000
# 827    11075      RICSU           8  1996-06-05 00:00:00.000
# 828    11076      BONAP           4  1996-06-05 00:00:00.000
# 829    11077      RATTC           1  1996-06-05 00:00:00.000
#
#                 RequiredDate              ShippedDate  ShipVia  Freight  \
# 0    1995-02-17 00:00:00.000  1995-01-24 00:00:00.000        2    47.42
# 1    1995-02-20 00:00:00.000  1995-01-26 00:00:00.000        1   126.38
# ...

# %% [markdown]
# # **Take a quick look at the dimensions of the two DataFrames**

# %%
Customers.shape
# Out:
# (91, 11)

# %%
Orders.shape
# Out:
# (830, 14)

# %% [markdown]
# # **Merge the Sheets(Inner Join)**
# Now to merge the two CSV files you have to use the dataframe.merge() method and define the column, you want to do merging.  If the data is not available for the specific columns in the other sheets then the corresponding rows will be deleted. You can verify using the shape() method. Use the following code.

# %%
merged_data = Orders.merge(Customers,on=["CustomerID"])
Orders.head(1000)
# Out:
#      OrderID CustomerID  EmployeeID                OrderDate  \
# 0      10389      BOTTM           4  1995-01-20 00:00:00.000
# 1      10390      ERNSH           6  1995-01-23 00:00:00.000
# 2      10391      DRACD           3  1995-01-23 00:00:00.000
# 3      10392      PICCO           2  1995-01-24 00:00:00.000
# 4      10393      SAVEA           1  1995-01-25 00:00:00.000
# ..       ...        ...         ...                      ...
# 825    11073      PERIC           2  1996-06-04 00:00:00.000
# 826    11074      SIMOB           7  1996-06-05 00:00:00.000
# 827    11075      RICSU           8  1996-06-05 00:00:00.000
# 828    11076      BONAP           4  1996-06-05 00:00:00.000
# 829    11077      RATTC           1  1996-06-05 00:00:00.000
#
#                 RequiredDate              ShippedDate  ShipVia  Freight  \
# 0    1995-02-17 00:00:00.000  1995-01-24 00:00:00.000        2    47.42
# 1    1995-02-20 00:00:00.000  1995-01-26 00:00:00.000        1   126.38
# ...

# %% [markdown]
# # **Other Things you can Do**
# Now there is a case when you want to append the rows only of one sheet to another sheet and vice-versa. To this, you have to use concate() method. Suppose I have two sheets of the same dataset and I want to work on a single sheet. Then I have to first add all the rows of one sheet to another. After that I can do anything from that dataset. Below is the code for appending the rows in a Dataframe.

# %%
concate_data = pd.concat([Orders,Customers])
concate_data.head(1000)
# Out:
#     OrderID CustomerID  EmployeeID                OrderDate  \
# 0   10389.0      BOTTM         4.0  1995-01-20 00:00:00.000
# 1   10390.0      ERNSH         6.0  1995-01-23 00:00:00.000
# 2   10391.0      DRACD         3.0  1995-01-23 00:00:00.000
# 3   10392.0      PICCO         2.0  1995-01-24 00:00:00.000
# 4   10393.0      SAVEA         1.0  1995-01-25 00:00:00.000
# ..      ...        ...         ...                      ...
# 86      NaN      WARTH         NaN                      NaN
# 87      NaN      WELLI         NaN                      NaN
# 88      NaN      WHITC         NaN                      NaN
# 89      NaN      WILMK         NaN                      NaN
# 90      NaN      WOLZA         NaN                      NaN
#
#                RequiredDate              ShippedDate  ShipVia  Freight  \
# 0   1995-02-17 00:00:00.000  1995-01-24 00:00:00.000      2.0    47.42
# 1   1995-02-20 00:00:00.000  1995-01-26 00:00:00.000      1.0   126.38
# ...

# %% [markdown]
# ## **Inner Join**

# %%
inner_merged_total = pd.merge(Orders, Customers, on=["CustomerID"])
inner_merged_total.head(1000)
# Out:
#      OrderID CustomerID  EmployeeID                OrderDate  \
# 0      10389      BOTTM           4  1995-01-20 00:00:00.000
# 1      10410      BOTTM           3  1995-02-10 00:00:00.000
# 2      10411      BOTTM           9  1995-02-10 00:00:00.000
# 3      10431      BOTTM           4  1995-03-02 00:00:00.000
# 4      10492      BOTTM           3  1995-05-02 00:00:00.000
# ..       ...        ...         ...                      ...
# 825    11043      SPECD           5  1996-05-22 00:00:00.000
# 826    10858      LACOR           2  1996-02-29 00:00:00.000
# 827    10927      LACOR           4  1996-04-04 00:00:00.000
# 828    10972      LACOR           4  1996-04-23 00:00:00.000
# 829    10973      LACOR           6  1996-04-23 00:00:00.000
#
#                 RequiredDate              ShippedDate  ShipVia  Freight  \
# 0    1995-02-17 00:00:00.000  1995-01-24 00:00:00.000        2    47.42
# 1    1995-03-10 00:00:00.000  1995-02-15 00:00:00.000        3     2.40
# ...

# %%
inner_merged_total.shape
# Out:
# (830, 24)

# %% [markdown]
# # **Outer Join**

# %%
outer_merged = pd.merge(Orders, Customers, how="outer", on=["CustomerID"])
outer_merged.head(1000)
# Out:
#      OrderID CustomerID  EmployeeID                OrderDate  \
# 0    10389.0      BOTTM         4.0  1995-01-20 00:00:00.000
# 1    10410.0      BOTTM         3.0  1995-02-10 00:00:00.000
# 2    10411.0      BOTTM         9.0  1995-02-10 00:00:00.000
# 3    10431.0      BOTTM         4.0  1995-03-02 00:00:00.000
# 4    10492.0      BOTTM         3.0  1995-05-02 00:00:00.000
# ..       ...        ...         ...                      ...
# 827  10927.0      LACOR         4.0  1996-04-04 00:00:00.000
# 828  10972.0      LACOR         4.0  1996-04-23 00:00:00.000
# 829  10973.0      LACOR         6.0  1996-04-23 00:00:00.000
# 830      NaN      FISSA         NaN                      NaN
# 831      NaN      PARIS         NaN                      NaN
#
#                 RequiredDate              ShippedDate  ShipVia  Freight  \
# 0    1995-02-17 00:00:00.000  1995-01-24 00:00:00.000      2.0    47.42
# 1    1995-03-10 00:00:00.000  1995-02-15 00:00:00.000      3.0     2.40
# ...

# %%
outer_merged.shape
# Out:
# (832, 24)

# %% [markdown]
# ## **Left Join**

# %% [markdown]
# **1) Left table Customers**

# %%
left_merged_01 = pd.merge(Customers, Orders, how="left", on=["CustomerID"])
left_merged_01.head(1000)
# Out:
#     CustomerID          CompanyName              ContactName  \
# 0        ALFKI  Alfreds Futterkiste             Maria Anders
# 1        ALFKI  Alfreds Futterkiste             Maria Anders
# 2        ALFKI  Alfreds Futterkiste             Maria Anders
# 3        ALFKI  Alfreds Futterkiste             Maria Anders
# 4        ALFKI  Alfreds Futterkiste             Maria Anders
# ..         ...                  ...                      ...
# 827      WOLZA       Wolski  Zajazd  Zbyszek Piestrzeniewicz
# 828      WOLZA       Wolski  Zajazd  Zbyszek Piestrzeniewicz
# 829      WOLZA       Wolski  Zajazd  Zbyszek Piestrzeniewicz
# 830      WOLZA       Wolski  Zajazd  Zbyszek Piestrzeniewicz
# 831      WOLZA       Wolski  Zajazd  Zbyszek Piestrzeniewicz
#
#              ContactTitle          Address      City Region PostalCode  \
# 0    Sales Representative    Obere Str. 57    Berlin    NaN      12209
# 1    Sales Representative    Obere Str. 57    Berlin    NaN      12209
# ...

# %%
left_merged_01.shape
# Out:
# (832, 24)

# %% [markdown]
# **2) Left table Orders**

# %%
left_merged_02 = pd.merge(Orders, Customers,  how="left", on=["CustomerID"])
left_merged_01.head(1000)
# Out:
#     CustomerID          CompanyName              ContactName  \
# 0        ALFKI  Alfreds Futterkiste             Maria Anders
# 1        ALFKI  Alfreds Futterkiste             Maria Anders
# 2        ALFKI  Alfreds Futterkiste             Maria Anders
# 3        ALFKI  Alfreds Futterkiste             Maria Anders
# 4        ALFKI  Alfreds Futterkiste             Maria Anders
# ..         ...                  ...                      ...
# 827      WOLZA       Wolski  Zajazd  Zbyszek Piestrzeniewicz
# 828      WOLZA       Wolski  Zajazd  Zbyszek Piestrzeniewicz
# 829      WOLZA       Wolski  Zajazd  Zbyszek Piestrzeniewicz
# 830      WOLZA       Wolski  Zajazd  Zbyszek Piestrzeniewicz
# 831      WOLZA       Wolski  Zajazd  Zbyszek Piestrzeniewicz
#
#              ContactTitle          Address      City Region PostalCode  \
# 0    Sales Representative    Obere Str. 57    Berlin    NaN      12209
# 1    Sales Representative    Obere Str. 57    Berlin    NaN      12209
# ...

# %%
left_merged_02.shape
# Out:
# (830, 24)

# %% [markdown]
# ## **Right Join**

# %%
 right_merged_01 = pd.merge(Customers, Orders, how="right", on=["CustomerID"])
 right_merged1.head(1000)
# Out:
#     CustomerID                 CompanyName          ContactName  \
# 0        BOTTM       Bottom-Dollar Markets    Elizabeth Lincoln
# 1        ERNSH                Ernst Handel        Roland Mendel
# 2        DRACD    Drachenblut Delikatessen         Sven Ottlieb
# 3        PICCO            Piccolo und mehr          Georg Pipps
# 4        SAVEA          Save-a-lot Markets       Jose Pavarotti
# ..         ...                         ...                  ...
# 825      PERIC   Pericles Comidas clásicas  Guillermo Fernández
# 826      SIMOB               Simons bistro       Jytte Petersen
# 827      RICSU          Richter Supermarkt         Michael Holz
# 828      BONAP                    Bon app'     Laurence Lebihan
# 829      RATTC  Rattlesnake Canyon Grocery         Paula Wilson
#
#                        ContactTitle                   Address         City  \
# 0                Accounting Manager        23 Tsawassen Blvd.    Tsawassen
# ...

# %% [markdown]
# # **pandas .join(): Combining Data on a Column or Index**

# %%
Orders.join( Customers, lsuffix="_left", rsuffix="_right").head(1000)
# Out:
#      OrderID CustomerID_left  EmployeeID                OrderDate  \
# 0      10389           BOTTM           4  1995-01-20 00:00:00.000
# 1      10390           ERNSH           6  1995-01-23 00:00:00.000
# 2      10391           DRACD           3  1995-01-23 00:00:00.000
# 3      10392           PICCO           2  1995-01-24 00:00:00.000
# 4      10393           SAVEA           1  1995-01-25 00:00:00.000
# ..       ...             ...         ...                      ...
# 825    11073           PERIC           2  1996-06-04 00:00:00.000
# 826    11074           SIMOB           7  1996-06-05 00:00:00.000
# 827    11075           RICSU           8  1996-06-05 00:00:00.000
# 828    11076           BONAP           4  1996-06-05 00:00:00.000
# 829    11077           RATTC           1  1996-06-05 00:00:00.000
#
#                 RequiredDate              ShippedDate  ShipVia  Freight  \
# 0    1995-02-17 00:00:00.000  1995-01-24 00:00:00.000        2    47.42
# ...

# %%
Customers.join( Orders, lsuffix="_left", rsuffix="_right").head(1000)
# Out:
#    CustomerID_left                         CompanyName  \
# 0            ALFKI                 Alfreds Futterkiste
# 1            ANATR  Ana Trujillo Emparedados y helados
# 2            ANTON             Antonio Moreno Taquería
# 3            AROUT                     Around the Horn
# 4            BERGS                  Berglunds snabbköp
# ..             ...                                 ...
# 86           WARTH                      Wartian Herkku
# 87           WELLI              Wellington Importadora
# 88           WHITC                White Clover Markets
# 89           WILMK                         Wilman Kala
# 90           WOLZA                      Wolski  Zajazd
#
#                 ContactName               ContactTitle  \
# 0              Maria Anders       Sales Representative
# 1              Ana Trujillo                      Owner
# 2            Antonio Moreno                      Owner
# 3              Thomas Hardy       Sales Representative
# ...

# %% [markdown]
# ## **Notes 1**
#
# https://realpython.com/pandas-merge-join-and-concat/#right-join
